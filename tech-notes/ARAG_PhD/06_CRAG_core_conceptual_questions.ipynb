# %% [markdown]
# # CRAG Core Conceptual Questions

# %% [markdown]
# # and Reflections

# %% [markdown]
# # 🧠 CRAG Core Conceptual Questions & Research Reflection
#
# > This is a markdown notebook designed to help you digest the CRAG framework deeply, stimulate your own research insights, and build your future PhD thesis foundation. Each question includes a prompt, a thinking guide, and space to write structured reflections.
#
# ---
#
# ## ❓ Q1: 為什麼Retrieval Evaluator 是RAG正確生成的關鍵？
#
# **Thinking Prompt:**
# - Is generation quality primarily a function of language model capability or input document relevance?
# - What happens when irrelevant documents are included?
#
# **Reflection Structure:**
# - 🌱 Observation:
# - 🎯 Hypothesis:
# - 🔍 Evidence from CRAG:
# - 🧠 My Insight:
#
# ---
#
# ## ❓ Q2: RAG該如何決定是否信任retrieved documents？誰該做這個判斷？
#
# **Thinking Prompt:**
# - Why not let the LLM decide directly?
# - What’s the tradeoff between dedicated small evaluator vs. integrated evaluator?
#
# **Reflection Structure:**
# - 🔄 Comparison: [T5 evaluator vs. integrated LLM logic]
# - ✅ Pros / Cons:
# - 🧪 Potential Alternative:
# - 🧠 My Insight:
#
# ---
#
# ## ❓ Q3: 為什麼需要Correct / Incorrect / Ambiguous三分支？
#
# **Thinking Prompt:**
# - Why not binary decision?
# - What does “ambiguous” represent epistemologically?
#
# **Reflection Structure:**
# - 🧠 Ambiguity as a signal of uncertainty:
# - 🔍 How does this impact robustness?
# - 💡 Could we model it probabilistically?
#
# ---
#
# ## ❓ Q4: Decompose-then-Recompose是為了解決什麼問題？
#
# **Thinking Prompt:**
# - Why not send entire documents to LLM directly?
# - What’s the impact of irrelevant context on generation?
#
# **Reflection Structure:**
# - 📂 Problems of full-document ingestion:
# - 🔍 Key benefit of strip-wise evaluation:
# - 🧠 My variation / idea:
#
# ---
#
# ## ❓ Q5: Relevance ≠ Correctness — 那CRAG的評估器是否會誤判？
#
# **Thinking Prompt:**
# - Can a highly relevant document still contain wrong information?
# - Is it enough to score based on similarity to query?
#
# **Reflection Structure:**
# - 🔍 Limits of current scoring:
# - 💡 What signals might help bridge this gap?
# - 🧠 My proposal:
#
# ---
#
# ## ❓ Q6: CRAG中最容易失誤的模組是哪個？為什麼？
#
# **Thinking Prompt:**
# - If it breaks, how does that propagate error?
# - What is the most fragile assumption in CRAG?
#
# **Reflection Structure:**
# - ⚠️ Fragility point:
# - 🧪 Failure scenario:
# - 🧠 How to improve or defend:
#
# ---
#
# ## ❓ Q7: Web Search 在CRAG中的角色真的是「補充」嗎？
#
# **Thinking Prompt:**
# - When might it be the main knowledge source?
# - Can search engines replace static corpora?
#
# **Reflection Structure:**
# - 🔍 CRAG’s treatment of web search:
# - 🌐 My proposed future use:
# - 📎 Tool integration idea:
#
# ---
#
# ## ❓ Q8: CRAG能否進化為loop-based correction agent？
#
# **Thinking Prompt:**
# - What happens if we allow multi-round judgment and correction?
# - Can evaluator feedback influence new retrieval?
#
# **Reflection Structure:**
# - 🔁 What is currently “1-shot” in CRAG?
# - 🧭 Multi-round correction idea:
# - 🧠 How to regulate loop termination:
#
# ---
#
# ## ❓ Q9: 為什麼CRAG模塊能Plug-and-play？它如何做到低耦合設計？
#
# **Thinking Prompt:**
# - How modular is the evaluator? The refinement module?
# - What assumptions allow easy swapping?
#
# **Reflection Structure:**
# - 🧱 Modular design notes:
# - 🧪 Interface boundary examples:
# - 🧠 Inspiration for Agentic CRAG:
#
# ---
#
# ## ❓ Q10: 什麼才是“真正智能的知識利用”？CRAG目前做到哪裡？
#
# **Thinking Prompt:**
# - What makes a system “know when it doesn’t know”?
# - Does CRAG represent this ideal, or is it the first step?
#
# **Reflection Structure:**
# - 🧠 Definition of intelligent knowledge use:
# - 🔍 CRAG’s limitations:
# - 💡 My roadmap toward a fully intelligent system:
#
# ---
#
# > ✍️ 每題花 20–40 分鐘書寫一輪，持續 10 週，博士腦框架將逐漸成型。
# > 📚 可擴展成思辨文章、開場演講、或 proposal 中的文獻省思段落。
